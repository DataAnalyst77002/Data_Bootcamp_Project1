# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint

import warnings
warnings.filterwarnings('ignore')

from scipy.stats import sem

list_detail = "airbnb-open-data-in-nyc/listings_detail.csv"
list_summary = "airbnb-open-data-in-nyc/listings_summary.csv"
list_reviewdet = "airbnb-open-data-in-nyc/reviews_detail.csv"
list_calenndar_detail = "airbnb-open-data-in-nyc/calendar_detail.csv"

ld_df = pd.read_csv(list_detail)
ls_df = pd.read_csv(list_summary)
lrd_df = pd.read_csv(list_reviewdet)
cd_df = pd.read_csv(list_calenndar_detail)

pd.DataFrame(ld_df)
# Out:
#              id                            listing_url     scrape_id  \
# 0      18461891  https://www.airbnb.com/rooms/18461891  2.017100e+13
# 1      20702398  https://www.airbnb.com/rooms/20702398  2.017100e+13
# 2       6627449   https://www.airbnb.com/rooms/6627449  2.017100e+13
# 3      19949243  https://www.airbnb.com/rooms/19949243  2.017100e+13
# 4       1886820   https://www.airbnb.com/rooms/1886820  2.017100e+13
# 5       5557381   https://www.airbnb.com/rooms/5557381  2.017100e+13
# 6      19609887  https://www.airbnb.com/rooms/19609887  2.017100e+13
# 7       7949480   https://www.airbnb.com/rooms/7949480  2.017100e+13
# 8      21057372  https://www.airbnb.com/rooms/21057372  2.017100e+13
# 9      16042478  https://www.airbnb.com/rooms/16042478  2.017100e+13
# 10      9147025   https://www.airbnb.com/rooms/9147025  2.017100e+13
# 11      1936633   https://www.airbnb.com/rooms/1936633  2.017100e+13
# 12     19758402  https://www.airbnb.com/rooms/19758402  2.017100e+13
# ...

# %%
pd.DataFrame(ls_df)
# Out:
#              id                                               name    host_id  \
# 0      18461891     Bright, comfortable 1B studio near everything!     916092
# 1      20702398                         Quiet house on City Island    1457680
# 2       6627449                     Large 1 BDRM in Great location   13886510
# 3      19949243                            Stay aboard  a sailboat    1149260
# 4       1886820                     Quaint City Island Community.     9815788
# 5       5557381                            Quaint City Island Home   28811542
# 6      19609887                                      Sweet Getaway  137892083
# 7       7949480  City Island Sanctuary BR & Private Bath w Parking     119445
# 8      21057372                     Relax and unwind on the water.  151702414
# 9      16042478                        WATERFRONT STUDIO APARTMENT    9117975
# 10      9147025                           Cozy City Island Cottage     403032
# ...

# %%
pd.DataFrame(lrd_df)
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 0          9452127   58944174    1/5/2016      6279455          Ravi
# 1          9452127   59446510   1/10/2016     23770684          Shiv
# 2          9452127   59557387   1/11/2016     29070567       Jandall
# 3          9452127   62664325   2/15/2016     58381183          Cody
# 4          9452127   63410004   2/22/2016     29014080        Magnus
# 5          9452127   66275129   3/20/2016     62596970        Aleeph
# 6          9452127   68607539    4/5/2016     64288274           Roy
# 7          9452127   70009847   4/15/2016     59071346    Frederique
# 8          9452127   70385596   4/17/2016     64934661       Jeffrey
# 9          9452127   70855836   4/21/2016     10147136     Stephanie
# 10         9452127   71406983   4/25/2016     36661817         Gavin
# 11         9452127   72236093    5/1/2016     44774424        Thomas
# 12         9452127   74459903   5/15/2016     62342928         Meera
# ...

# %%
pd.DataFrame(cd_df)
# Out:
#          listing_id        date available     price
# 0              2515   10/1/2018         t   $99.00
# 1              2515   9/30/2018         t   $89.00
# 2              2515   9/29/2018         t   $99.00
# 3              2515   9/28/2018         t   $99.00
# 4              2515   9/27/2018         t   $99.00
# 5              2515   9/26/2018         t   $99.00
# 6              2515   9/25/2018         t   $99.00
# 7              2515   9/24/2018         t   $99.00
# 8              2515   9/23/2018         t   $99.00
# 9              2515   9/22/2018         t   $99.00
# 10             2515   9/21/2018         t   $99.00
# 11             2515   9/20/2018         t   $99.00
# 12             2515   9/19/2018         t   $99.00
# 13             2515   9/18/2018         t   $99.00
# 14             2515   9/17/2018         t   $99.00
# 15             2515   9/16/2018         t   $99.00
# 16             2515   9/15/2018         t   $99.00
# ...

# %%
#Merge list_detail and list summary

# combined_mouse_trial = pd.merge(clinical_df, mouse_drug_df,
#                                  how='outer', on='Mouse ID')

comb_data = pd.merge(ld_df, ls_df,
                    how='outer', on='id')

comb_data

# comb_data = comb_data.id.unique()

# count = comb_data.id.drop_duplicates()

# count
# Out:
#              id                            listing_url     scrape_id  \
# 0      18461891  https://www.airbnb.com/rooms/18461891  2.017100e+13
# 1      20702398  https://www.airbnb.com/rooms/20702398  2.017100e+13
# 2       6627449   https://www.airbnb.com/rooms/6627449  2.017100e+13
# 3      19949243  https://www.airbnb.com/rooms/19949243  2.017100e+13
# 4       1886820   https://www.airbnb.com/rooms/1886820  2.017100e+13
# 5       5557381   https://www.airbnb.com/rooms/5557381  2.017100e+13
# 6      19609887  https://www.airbnb.com/rooms/19609887  2.017100e+13
# 7       7949480   https://www.airbnb.com/rooms/7949480  2.017100e+13
# 8      21057372  https://www.airbnb.com/rooms/21057372  2.017100e+13
# 9      16042478  https://www.airbnb.com/rooms/16042478  2.017100e+13
# 10      9147025   https://www.airbnb.com/rooms/9147025  2.017100e+13
# 11      1936633   https://www.airbnb.com/rooms/1936633  2.017100e+13
# 12     19758402  https://www.airbnb.com/rooms/19758402  2.017100e+13
# ...

# %%
# comb_data.to_csv("comb_data.csv", encoding='utf-8')

# %%
df1 = comb_data[['id','review_scores_rating', 'price_x', 'host_name_x']]

df1
# Out:
#              id  review_scores_rating   price_x        host_name_x
# 0      18461891                   NaN  $110.00          Connie Mae
# 1      20702398                 100.0   $50.00               James
# 2       6627449                  95.0  $125.00              Arlene
# 3      19949243                   NaN  $100.00                MoMo
# 4       1886820                   NaN  $300.00               Steve
# 5       5557381                  97.0   $69.00              Phoebe
# 6      19609887                 100.0  $150.00              Gladis
# 7       7949480                 100.0  $101.00      Linda & Didier
# 8      21057372                   NaN  $100.00               David
# 9      16042478                   NaN  $200.00             Collins
# 10      9147025                  97.0  $125.00               Diane
# 11      1936633                  99.0  $115.00                Alex
# 12     19758402                  87.0   $62.00                 Deb
# ...
